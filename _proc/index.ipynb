# %% [raw]
# ---
# description: Trading environments for Gymnasium library
# output-file: index.html
# title: gym-trading
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install gym_trading in Development mode

# %% [markdown]
# ```sh
# # make sure gym_trading package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to gym_trading
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/neurion-ai/gym-trading.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c neurion-ai gym_trading
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install gym_trading
# ```
#
#
# [repo]: https://github.com/neurion-ai/gym-trading
# [docs]: https://neurion-ai.github.io/gym-trading/
# [pypi]: https://pypi.org/project/gym-trading/
# [conda]: https://anaconda.org/neurion-ai/gym-trading

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/neurion-ai/gym-trading
# [docs]: https://neurion-ai.github.io/gym-trading/
# [pypi]: https://pypi.org/project/gym-trading/
# [conda]: https://anaconda.org/neurion-ai/gym-trading

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
